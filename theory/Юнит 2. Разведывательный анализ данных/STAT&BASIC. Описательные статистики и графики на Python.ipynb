# %% [markdown]
# # 1.1. О чём этот модуль?
# Как правило, данные представляют собой набор чисел. Например, такой:
#
# Нелегко сразу осмыслить этот набор и сделать выводы, не так ли?
#
# Чтобы внести в эти данные порядок и ясность, их нужно описать. Закономерный вопрос — как?
#
# Ответу на этот вопрос посвящён настоящий модуль. Мы поговорим о том, как описать набор данных и сделать первичные выводы с помощью двух типов инструментов:
#
# описательных статистик;
# графиков.
# В этом модуле мы оставим в стороне графики и сфокусируемся на описательных статистиках.
#
# Презентацию, с которой работает автор, можно посмотреть здесь(https://lms.skillfactory.ru/assets/courseware/v1/898de0c0bde1d5d6168c213754fb45ed/asset-v1:Skillfactory+DST-WEEKLY-2.0+08JULY2020+type@asset+block/SkillFactory_Module_on_Descriptives-formated-new.pdf).

# %% [markdown]
# # 1.2. Описательные статистики
# Можно сказать, что описательная статистика — это формула, которая использует весь набор данных и дает нам ответ в виде одного числа.
#
# Например, у нас есть такой набор чисел:
#
# 23, 45, 23, 44, 34, 56, 54, 12, 11, 44, 44, 31, 4, 30, 20, 49, 38, 48, 38, 40, 36, 41, 33, 47, 32
#
# Каждое число здесь показывает количество контрактов, заключенных в течение одного года одним менеджером по продажам.
#
# С первого взгляда сложно понять, о чём могут сказать эти разрозненные числа. Результаты, полученные для нашей выборки (некоторой группы объектов, которые мы исследуем) интересуют нас не по отдельности для каждого объекта — нас интересует какая-то обобщённая оценка.
#
# Нам необходимо как-то оценить, описать распределение интересующих нас признаков в обобщенном виде. Для этого в первую очередь нам нужно знать, какие значения являются наиболее типичными для этого признака, что для него наиболее характерно. Для этого мы будем вычислять меры центральной тенденции, или меры центра.
#
# Всего есть три меры центральной тенденции:
#
# - Среднее (среднее арифметическое всех значений).
# - Медиана (серединное значение).
# - Мода (наиболее частое наблюдение).
#
# Но найденная мера центральной тенденции не позволит нам полностью описать признак. Например, мы знаем, что средний чек в ресторане за неделю составил 1000 руб. Это значение может быть получено разными способами: например, все посетители потратили по 1000 руб. Ровно такое же среднее арифметическое будет в ситуации, когда половина посетителей потратила по 500 руб., а другая — по 1500 руб. Конечно, это будут совершенно разные ситуации.
#
# Поэтому ещё один вопрос, который необходимо задать: а насколько сильно разбросаны друг относительно друга значения?
#
# Для ответа на такой вопрос существуют меры разброса.
#
# Вот самые популярные меры разброса:
#
# - Дисперсия.
# - Стандартное отклонение.
# - Размах.
# - Межквартильный размах.

# %% [markdown]
# # 1.3. Важные термины
# Прежде чем мы перейдем к тому, как именно вычислять описательные статистики, поговорим немного о терминах. Они помогут нам быстро называть операции над данными и записывать их.
#
# **Случайная величина**. Это то, с чем мы работаем. Случайной она называется потому, что когда мы выбираем какое-либо число из набора данных, мы не знаем, каким оно окажется. Обозначается большой буквой, например _X_.
# В нашем примере случайная величина — это количество контрактов, заключенных одним менеджером в течение года.
#
# **Наблюдение**. Это конкретное значение случайной величины. Обозначается маленькой буквой, например _x_.
#
# _x5=41_
#
# Означает, что пятый менеджер заключил 41 контракт.
#
# **Генеральная совокупность**. Это все множество объектов, которое нас интересует. В нашем примере генеральная совокупность — это все менеджеры по продажам внутри большой международной компании. Обозначается большой буквой _N_.
# Например, _N = 1000_.
#
# **Выборка**. Поскольку в реальной жизни, как правило, у нас нет информации обо всей генеральной совокупности, нам приходится работать с какой-то ее частью. Эта часть генеральной совокупности и называется выборкой. Обозначается маленькой буквой _n_. Например, _n = 25_.
#
# Важно!
# Следует всегда помнить, с чем нам приходится работать — с выборкой или с генеральной совокупностью. Это повлияет на выбранный нами способ расчетов.

# %% [markdown]
# # 1.4. Меры центра
# СРЕДНЕЕ
#
# Самая интуитивно понятная мера центральной тенденции, которая сразу приходит на ум — это среднее арифметическое. Мы достаточно часто используем эту меру в повседневной жизни. К примеру, если мы хотим узнать об уровне обучения в какой-то школе, мы можем посмотреть средний балл ЕГЭ её выпускников и оценить, насколько качественные знания дают в этом учебном заведении. Или, представим, что мы хотим перекусить в кафе и хотим понять, хватит ли нам денег. В таком случае мы можем выбирать только те кафе, средний чек которых не слишком для нас высок.
#
# Среднее бывает выборочным и истинным — в зависимости от того, какой у нас есть набор данных (выборка или генеральная совокупность).
#
# Выборочное среднее — это просто среднее арифметическое всех наблюдений, то есть сумма наблюдений, поделенная на их количество. Обозначается  (x с вертикальной верхней чертой).
#
# ![image.png](attachment:image.png)
#
# Считаем выборочное среднее по нашим данным:
#
# ![image-2.png](attachment:image-2.png)
#
# Истинное среднее рассчитывается на основе всех значений генеральной совокупности. Обозначается греческой буквой «мю».
#
# ![image-3.png](attachment:image-3.png)
#
# Однако у среднего арифметического как у меры центральной тенденции есть существенный минус. Эта мера чувствительна к выбросам.
#
# А ЧТО ТАКОЕ ВЫБРОС?
#
# Представим, что мы хотим вычислить среднюю зарплату и отобрали 10 сотрудников с зарплатой 30 000 и одного топ-менеджера с зарплатой 500 000. Вычислим среднюю зарплату для этих людей:
#
# ![image-4.png](attachment:image-4.png)
#
# Мы можем видеть, что из-за большой зарплаты топ-менеджера средняя зарплата увеличилась и не отражает действительности.
#
# Или другой пример. Если мы возьмем группу людей со средним уровнем интеллекта, то человек с очень высоким уровнем интеллекта (к примеру Эйнштейн) будет выбросом. Человек с очень низким уровнем интеллекта (например, имеющий некие особенности развития) также будет выбросом.
#
# Есть несколько путей борьбы с этой проблемой. Во-первых, можно вычислять усечённое среднее. Для того, чтобы его найти, нужно отбросить самые маленькие и самые большие значения (например, по 5 % с каждой стороны) и вычислять среднее уже по такой урезанной выборке. Отсекая самые маленькие и самые большие значения, мы избавляемся от выбросов, и результат получается более релевантный.
#
# → Также можно специально выбрать именно те значения, которые являются выбросами. Мы научимся делать это чуть позднее.
#
# Есть и другой путь: вычислять показатели, не чувствительные к выбросам (их называют робастными). Аналог среднего арифметического, который не чувствителен к выбросам, — это медиана ↓
#
# МЕДИАНА
#
# Медиана — это значение, разделяющее набор данных на две половины: одна ниже медианы, другая выше.
#
# Как найти медиану?
#
# Упорядочить все наблюдения по возрастанию.
# Найти середину.
# Многое в нахождении медианы зависит от того, четное или нечетное количество наблюдений.
#
# ![image-7.png](attachment:image-7.png)
#
# СРЕДНЕЕ VS МЕДИАНА
#
# Что лучше — среднее или медиана? Все зависит от того, есть ли в нашем наборе данных нетипичные наблюдения (выбросы). Допустим, если в набор данных о доходах затесались доходы миллионера, наше среднее будет говорить вовсе не о типичном значении.
#
# Посмотрим на слабые и сильные стороны среднего и медианы:
# ![image-8.png](attachment:image-8.png)
#
# МОДА
#
# Есть и ещё одна мера центральной тенденции — это мода.
#
# Мода — это наиболее частое наблюдение в наборе данных.
#
# В нашем случае это 44, единственное наблюдение, которое встретилось три раза.
#
# Мода используется не так часто, но иногда это единственный способ оценить самые типичные значения. Например, если у нас есть города проживания для какого-то количества людей, то мы не можем найти среднее арифметическое для городов, не можем их проранжировать для поиска медианы, но зато мы можем найти самый часто встречающийся город — моду.

# %% [markdown]
# Какие меры оценивают центральные (или типичные) наблюдения? Выберите все верные варианты.
# - Среднее арифметическое
# - Мода
# - Медиана

# %% [markdown]
# Какая мера необходима для нахождения самого часто встречающегося значения?
# - Мода
#
# Для каких из перечисленных случаев медиана подходит как мера центральной тенденции?
# - Присутствуют выбросы
# - Необходимо разделить числовой ряд пополам
#
# Среднее арифметическое пяти чисел равно 8,2. Четыре из этих чисел — 6, 10, 7 и 12. Найдите пятое число.
# Ответ: 6 (8,2*5 - (6+7+10+12))

# %% [markdown]
# Итак, среднее — это сумма значений, поделённая на их количество. Допустим, в классе из 7 человек ученики получили следующие оценки:
# 4, 5, 3, 4, 2, 5, 5
# Дополните утверждения:
#
# Мода на 1 балл больше средней оценки.
#
# Этот набор данных является генеральной совокупностью.

# %% [markdown]
# # 1.5. Тренировка
# Задача с использованием Python
# Мужчины	80.2	80.8	57.5	98	50.5	73.8	77.4	59.7	77.9	52.6
# Женщины	57.9	57.3	72.8	48.2	59.5	48.3	61.2	53.9	53.9	70.7
#
# С помощью Python мы можем найти среднее значение списка, просто используя функцию mean(). Единственный аргумент этой функции — список данных, на котором необходимо посчитать значение.
#
# В таблице выше представлен ряд данных о весе 20 случайно выбранных клиентов медицинской клиники — 10 мужчин и 10 женщин (в кг). Скопируйте датафрейм, который описывают нашу таблицу, в свой ноутбук и выполните задание.

# %%
import pandas as pd

df = pd.DataFrame({
    'men': [80.2, 80.8, 57.5, 98, 50.5, 73.8, 77.4, 59.7, 77.9, 52.6],
    'women': [57.9, 57.3, 72.8, 48.2, 59.5, 48.3, 61.2, 53.9, 53.9, 70.7]
})

# %%
# Средний вес мужчины в данной выборке превышает средний вес женщины на 12.5 кг.
# Введите значение, округлив до 1 знака после точки-разделителя.
men_mean = df.men.mean()
women_mean = df.women.mean()
print(round(men_mean - women_mean, 1))
# Out:
# 12.5

# %%
# Дано два набора данных: 2, 7, 4, 3, 6, 4, 1, 2 и 5, 2, 4, 8, 1, 6, 7
set1 = pd.Series([2, 7, 4, 3, 6, 4, 1, 2])
set2 = pd.Series([5, 2, 4, 8, 1, 6, 7])
# Медиана в первом наборе данных равна 3.5. (введите значение с точкой в качестве разделителя)
set1_med = set1.median()
print(set1_med)
# Это на ____ меньше медианы во втором наборе данных. (введите значение с точкой в качестве разделителя)
set2_med = set2.median()
print(set2_med - set1_med)
# Out:
# 3.5
# 1.5

# %% [markdown]
# Задача с использованием Python
# Мужчины	80.2	80.8	57.5	98	50.5	73.8	77.4	59.7	77.9	52.6
# Женщины	57.9	57.3	72.8	48.2	59.5	48.3	61.2	53.9	53.9	70.7
#
# Следуя описанному в теоретической части алгоритму, мы можем написать вычисление медианы в Python по аналогии со средним арифметическим. Для этого нам понадобится функция median().
#
# Используя median(), найдем медиану списка данных, применив функцию ко всему датафрейму или по отдельности для каждой серии.
#
# Вспоминаем выборку из 20 пациентов.

# %%
df = pd.DataFrame({
    'men': [80.2, 80.8, 57.5, 98, 50.5, 73.8, 77.4, 59.7, 77.9, 52.6],
    'women': [57.9, 57.3, 72.8, 48.2, 59.5, 48.3, 61.2, 53.9, 53.9, 70.7]
})

# %%
# Медианный вес среди мужчин (введите значение с точкой в качестве разделителя):
men_med = df.men.median()
print(men_med)
# Медианный вес среди женщин (введите значение с точкой в качестве разделителя):
women_med = df.women.median()
print(women_med)

# Для создания общего списка пациентов объедините серии мужчин и женщин в один patients, а затем найдите медиану.
# Медианный вес всех пациентов в выборке (введите значение с точкой в качестве разделителя):
patients = pd.concat([df.men, df.women])
patients_med = patients.median()
print(patients_med)
# Out:
# 75.6
# 57.599999999999994
# 59.6

# %% [markdown]
# # 1.6. Квартили
# Давайте вспомним, что такое квартили и почему их так удобно использовать при анализе большого количества данных.
# ![image.png](attachment:image.png)

# %% [markdown]
# # КАК НАХОДИТЬ КВАРТИЛИ?
# ![image.png](attachment:image.png)

# %% [markdown]
# Мы здесь рассмотрели лишь один из способов поиска квартилей. Как это ни странно, квартили ищутся разными вариантами. В данном случае мы не использовали медиану при расчете квартилей — не брали её ни в первую половину ряда, ни во вторую. Такой метод подсчёта квартилей называется эксклюзивным (то есть исключающим медиану).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Возьмём два знакомых нам по третьей задаче набора данных:
# 2, 7, 4, 3, 6, 4, 1, 2
# и 
# 5, 2, 4, 8, 1, 6, 7
set1 = sorted([2, 7, 4, 3, 6, 4, 1, 2])
print(set1)
set2 = sorted([5, 2, 4, 8, 1, 6, 7])
print(set2)
# Найдите квартили (эксклюзивным методом) для обоих наборов данных 
set1_centr = len(set1)//2
set2_centr = len(set2)//2

set1_Q1 = pd.Series(set1[:set1_centr]).median()
print('set1_Q1', set1_Q1)
set2_Q1 = pd.Series(set2[:set2_centr]).median()
print('set2_Q1', set2_Q1)

set1_Q3 = pd.Series(set1[set1_centr:]).median()
print('set1_Q3', set1_Q3)
set2_Q3 = pd.Series(set2[set2_centr:]).median()
print('set2_Q3', set2_Q3)
# и выберите все верные утверждения из списка ниже:
# Нижний квартиль в первом наборе равен первому квартилю во втором наборе
# Верхний квартиль во втором наборе данных выше, чем в первом наборе данных
# Out:
# [1, 2, 2, 3, 4, 4, 6, 7]
# [1, 2, 4, 5, 6, 7, 8]
# set1_Q1 2.0
# set2_Q1 2.0
# set1_Q3 5.0
# set2_Q3 6.5

# %% [markdown]
# # 1.7. Тренировка
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Также у quantile()  существует необязательный параметр, который  указывает метод интерполяции, который нужно использовать, когда требуемый квантиль лежит между двумя точками данных. По умолчанию используется линейная интерполяция.

# %%
# DataFrame.quantile(q=0.5, axis=0, numeric_only=True, interpolation='linear')

# %% [markdown]
# Чтобы вычислять квантиль как среднее между двумя точками в части данных, необходимо сменить вид интерполяции на следующий:

# %%
# DataFrame.quantile(q=0.5, axis=0, numeric_only=True, interpolation='midpoint')

# %% [markdown]
# Более подробная информация о том, как работает параметр interpolation и какие еще виды интерполяции можно применить, есть в официальной документации(https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.quantile.html).
#
# Чтобы выполнить задания здесь и далее, используйте параметр интерполяции interpolation='midpoint'.

# %%
# Найдите Q1 и Q3 для мужчин и женщин, используя Python 
# (выпишите результат, округляя до 1 знака после точки-разделителя):
# Для того, чтобы округлить до 1 знака после точки-разделителя, 
# используйте round(value, 1), где value — это число для округления.
df = pd.DataFrame({
    'men': [80, 80.8, 57.5, 98, 50.5, 73.8, 77.4, 59.7, 77.9, 52.6],
    'women': [57.9, 57.3, 72.8, 48.2, 59.5, 48.3, 61.2, 53.9, 53.9, 70.7]
})
# Для мужчин:
# Q1
men_Q1 = round(df.men.quantile(q=0.25, interpolation='midpoint'), 1)
print('men_Q1' ,men_Q1)
# Q3
men_Q3 = round(df.men.quantile(q=0.75, interpolation='midpoint'), 1)
print('men_Q3', men_Q3)
# Для женщин:
# Q1
women_Q1 = round(df.women.quantile(q=0.25, interpolation='midpoint'), 1)
print('women_Q1' ,women_Q1)
# Q3
women_Q3 = round(df.women.quantile(q=0.75, interpolation='midpoint'), 1)
print('women_Q3', women_Q3)

# 25 % мужчин весят больше, чем 79.0 кг.
# Out:
# men_Q1 58.6
# men_Q3 79.0
# women_Q1 53.9
# women_Q3 60.4

# %% [markdown]
# # Размах
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Межквартильный размах
# ![image.png](attachment:image.png)

# %% [markdown]
# # Стандартное отклонение
# ![image.png](attachment:image.png)

# %% [markdown]
# # Как посчитать стандартное отклонение?
# ![image.png](attachment:image.png)

# %% [markdown]
# # А что с выборочным стандартным отклонением?
# ![image.png](attachment:image.png)

# %% [markdown]
# # Важно!
# Дисперсия и стандартные отклонения — это всегда не отрицательные числа.

# %% [markdown]
# # Что рассказали меры разброса о наших данных?
# ![image.png](attachment:image.png)

# %%
# Какие меры оценивают разброс в данных?
# Ответ:
# размах
# межквартильный размах
# стандартное отклонение

# %% [markdown]
# # 1.9. Тренировка
# Найдите размах и межквартильный размах для веса на выборке пациентов клиники.
#
# Мужчины	80.2	80.8	57.5	98	50.5	73.8	77.4	59.7	77.9	52.6
# Женщины	57.9	57.3	72.8	48.2	59.5	48.3	61.2	53.9	53.9	70.7

# %%
import pandas as pd
df = pd.DataFrame({
    'men': [80.2, 80.8, 57.5, 98, 50.5, 73.8, 77.4, 59.7, 77.9, 52.6],
    'women': [57.9, 57.3, 72.8, 48.2, 59.5, 48.3, 61.2, 53.9, 53.9, 70.7]
})

# %% [markdown]
# Для удобства вычисления размаха можете использовать стандартные функции min(), max() для серий в pandas. Также используйте знания о функции quantile() для вычисления межквартильного размаха. Используйте ранее приведенный параметр интерполяции для вычислени квартилей в pandas.

# %%
# Выпишите результат, округляя до 1 знака после точки-разделителя:
# Для мужчин:
# Размах
range_men = df.men.max() - df.men.min()
print(round(range_men, 1))
# IQR
IQR_men = df.men.quantile(q=0.75, interpolation='midpoint') - df.men.quantile(q=0.25, interpolation='midpoint')
print(round(IQR_men, 1))
# Для женщин:
# Размах
range_women = df.women.max() - df.women.min()
print(round(range_women, 1))
# IQR
IQR_women = IQR_men = df.women.quantile(q=0.75, interpolation='midpoint') - df.women.quantile(q=0.25, interpolation='midpoint')
print(round(IQR_women, 1))
# Разброс в значениях веса у мужчин ______, чем у женщин.
# Ответ: больше
# Out:
# 47.5
# 20.5
# 24.6
# 6.5

# %% [markdown]
# # Вычисляем стандартное отклонение в Python
# Для вычисления стандартного отклонения в выборке в Python используется функция std(). Единственным аргументом функции является диапазон данных. В данном случае диапазоном данных может выступать как серия pandas, так и весь датафрейм целиком. Aналогично для вычисления дисперсии используется функция var().

# %%
# Задание: Найдите дисперсию и стандартное отклонение веса для выборки пациентов клиники. 
# Выпишите результат, округляя до 1 знака после точки-разделителя:

# Для мужчин:
# Стандартное отклонение
std_men = df.men.std()
print(round(std_men, 1))
# Дисперсия
var_men = df.men.var()
print(round(var_men, 1))
# Для женщин:
# Стандартное отклонение
std_women = df.women.std()
print(round(std_women, 1))
# Дисперсия
var_women = df.women.var()
print(round(var_women, 1))

# Разброс в значениях веса у мужчин _______, чем у женщин.
# Ответ: больше
# __________измеряется так же, как и среднее, медиана и размах, в кг.
# Ответ: Стандартное отклонение
# Значение ____________ не имеет непосредственной интерпретации.

# Ответ: Дисперсии
# Out:
# 15.2
# 230.5
# 8.3
# 68.4

# %% [markdown]
# # 1.10. Выбросы
# ## ТЕОРИЯ: ВЫБРОСЫ
#
# **Выброс** — это нетипичное наблюдение, то есть такое наблюдение, которое существенно отличается от остальных в выборке.
#
# Например, когда в данные о доходах попадает наблюдение о доходах миллионера, оно существенно повлияет на описательные статистики.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Что делать с выбросами?
# Их можно удалить перед подсчетом описательных статистик и отдельно упомянуть в отчёте, что такие наблюдения были.

# %% [markdown]
# Проверьте наличие выбросов в выборке пациентов клиники:
#
# Мужчины	80.2	80.8	57.5	98	50.5	73.8	77.4	59.7	77.9	52.6
# Женщины	57.9	57.3	72.8	48.2	59.5	48.3	61.2	53.9	53.9	70.7

# %%
# Выборка мужчин-пациентов клиники ________________.
Q1_men = df.men.quantile(q=0.25, interpolation='midpoint')
Q3_men = df.men.quantile(q=0.75, interpolation='midpoint')
IQR_men = Q3_men - Q1_men
result = df[(df.men < Q1_men - (1.5*IQR_men)) | (df.men > Q3_men + (1.5*IQR_men))]
print(result.men)
# Ответ: не содержит выбросов

# Выборка женщин-пациентов клиники ________________.
Q1_women = df.women.quantile(q=0.25, interpolation='midpoint')
Q3_women = df.women.quantile(q=0.75, interpolation='midpoint')
IQR_women = Q3_women - Q1_women
result = df[(df.women < Q1_women - (1.5*IQR_women)) | (df.women > Q3_women + (1.5*IQR_women))]
print(result.women)
# Ответ: содержит выбросы
# Out:
# Series([], Name: men, dtype: float64)
# 2    72.8
# 9    70.7
# Name: women, dtype: float64

# %% [markdown]
# Таблица показывает среднюю температуру в январе (в градусах по Цельсию) в одном российском городе за 2007-2018 годы:
#
# 2007	2008	2009	2010	2011	2012	2013	2014	2015	2016	2017	2018
# -4.7	-6.1	-5.5	-3.3	-7.1	-3.1	-5.2	-7.3	-12.1	-6.6	-5.9	-6.3

# %%
# Ипользуйте датафрейм:

import pandas as pd
df = pd.DataFrame({
    'year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    'temp': [-4.7, -6.1, -5.5, -3.3, -7.1, -3.1, -5.2, -7.3, -12.1, -6.6, -5.9, -6.3]
})

# %%
# Используя Python, найдите описательные статистики средней январской температуры за 12 лет. 
# Ответы округлите до 1 знака после точки-разделителя.

# Среднее:
mean_temp = df.temp.mean()
print('mean_temp', round(mean_temp, 1))
# Медиана:
median_temp = df.temp.median()
print('median_temp', round(median_temp, 1))
# Стандартное отклонение:
std_temp = df.temp.std()
print('std_temp', round(std_temp, 1))
# Размах:

range_temp = df.temp.max() - df.temp.min()
print('range_temp', round(range_temp, 1))
# Межквартильный размах:
Q1_temp = df.temp.quantile(q=0.25, interpolation='midpoint')
Q3_temp = df.temp.quantile(q=0.75, interpolation='midpoint')
IQR_temp = Q3_temp - Q1_temp
print('IQR_temp', round(IQR_temp, 1))

# Выборка содержит выброс. Это случай особенно ___________ средней температуры...
ejection = df[(df.temp < Q1_temp - (1.5*IQR_temp)) | (df.temp > Q3_temp + (1.5*IQR_temp))]
print(ejection.temp)
# Ответ: низкой
# ...в январе ________ года.
print(ejection.year)
# Ответ: 2015
# Out:
# mean_temp -6.1
# median_temp -6.0
# std_temp 2.3
# range_temp 9.0
# IQR_temp 1.9
# 8   -12.1
# Name: temp, dtype: float64
# 8    2015
# Name: year, dtype: int64

# %% [markdown]
# # 1.11. Графики
# Ещё один способ содержательно и информативно описать данные — это графики.
#
# Здесь мы познакомимся с двумя самыми распространёнными их видами:
#
# - Box plot
# - Гистограмма

# %% [markdown]
# # Теория: box plot
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Подробнее о box plot
# ![image.png](attachment:image.png)

# %% [markdown]
# Если в наборе данных есть выбросы (по английски “outliers”), они будут обозначены отдельными точками (или другими знаками) за пределами основной области графика. В таком случае линии границ «усов» окажутся не в точках минимума и максимума, а на границах, в пределах которых находятся простые наблюдения, не являющиеся выбросами.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Строим графики в Python
# Разберемся с тем, как построить графики в python.
#
# Предположим, у нас есть данные о расходах на мобильную связь 20 пользователей в городе А и 20 пользователей в городе Б.

# %%
import pandas as pd
df = pd.DataFrame({
    'city_a': [240, 440, 455, 475, 475, 490, 490, 500, 500, 500, 530, 550, 578, 580, 620, 687, 694, 703, 859],
    'city_b': [500, 564, 590, 600, 600, 600, 645, 650, 660, 667, 689, 692, 700, 700, 705, 735, 760, 764, 805]
})

# %% [markdown]
# Для каждого столбца в фрейме данных можно создать boxplots — df.boxplot(), указав используемые столбцы:

# %%
boxplot = df.boxplot(column=['city_a', 'city_b'])

# %% [markdown]
# Графики строятся автоматически, нам не нужно ничего предварительно высчитывать. На графике визуально мы можем увидеть значения минимума, максимума (или границы простых значений, если есть выбросы) первого и третьего квартилей, медианы и выбросов (если таковые есть).

# %% [markdown]
# График можно вывести или сохранить в файл. В графиках доступно дополнительное форматирование, например:
#
# - скрыть сетку grid (grid=False);
# - вращение меток по оси x (т. е. rot=45);
# - изменение размера шрифта (т. е. fontsize=15).

# %% [markdown]
# Как описать график
# При описании графика необходимо помнить о нескольких элементах:
#
# - Меры типичных наблюдений (среднее, медиана, пик распределения для гистограммы);
# - Меры разброса (размах, межквартильный размах);
# - Форма распределения;
# - Другие особенности: наличие разрывов (gaps), выбросов (outliers), кластеров.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# На этих схематических графиках показано, как могут выглядеть гистограммы с различными формами распределения. На графиках a и b — симметричные распределения, c и d — несимметричные.
#
# На графике а изображено нормальное распределение (где очень близки друг к другу значения среднего, моды и медианы), а на графике b — бимодальное. В любом симметричном распределении значения среднего и медианы близки друг к другу, но в бимодальном распределении отличается от них значение моды. Несимметричные распределения описываются как смещенные.
#
# На графике c изображено смещенное вправо, или положительное распределение, потому что хвост длиннее справа. В этом случае среднее будет больше медианы. На графике d — смещенное влево, или отрицательное распределение. В этом случае среднее будет меньше медианы.
#
# Медиана в распределении делит наш график на две части, равные по площади. Значение среднего смещается в сторону длинного хвоста.
#
# Боксплот мы читаем примерно так же, только смотрим мы не на форму линии и ее размещение на площади графика, а на длину отрезков. На этом боксплоте мы видим распределение, смещенное вправо:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Интерпретируем график
# Давайте посмотрим, какую полезную информацию мы можем получить из двух графиков о расходах на мобильную связь в городе А и городе Б.
#
# ![image.png](attachment:image.png)
#
# - Сравниваем типичные наблюдения. В гистограмме смотрим на наиболее высокие столбцы (пики). Сразу заметно, что в городе Б пользователи тратят на мобильную связь больше, чем в городе А. На боксплоте видно, что медиана в городе А существенно ниже, чем в городе Б.
# - Сравниваем разброс в наблюдениях. Это легче всего увидеть по боксплоту. Но и по гистограмме тоже видно, что наблюдения по городу А более «распластаны» по площади графика. Это значит, что пользователи в городе А отличаются друг от друга больше, чем пользователи в городе Б.
# - Оцениваем форму распределения. Легче всего это сделать на гистограмме. Мы видим, что в городе Б распределение симметричное, а в городе А смещено вправо.
# - Оцениваем наличие других особенностей. В городе А есть один выброс.

# %%
# У распределения, смещенного вправо:
# Ответ: Длинный «хвост» справа и среднее больше медианы

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# На наборе данных был построен следующий boxploacorrt.
# Ответ: смещено влево 
# Исходя из ответа в предыдущем вопросе, что лучше использовать в качестве меры типичного наблюдения?
# Ответ: медиану

# %% [markdown]
# # 1.13. Тренировка

# %%
# В Python постройте boxplot на предложенном в предыдущей задаче наборе данных:
data = pd.DataFrame({
  'value': [48, 44, 42.5, 40.5, 40.5, 39, 39, 38, 38, 38, 35, 33, 30.2, 30, 26, 19.3, 27, 21]
})

# %%
# Найдите на графике отображение медианы. Чему она равна?
# Используйте data.median(axis=0) для нахождения численного значения медианы.
print(data.median(axis=0)[0])
# Out:
# 38.0

# %% [markdown]
# # Задание 1.13.2
# ![image.png](attachment:image.png)

# %%
import pandas as pd
df = pd.DataFrame({
    'group_a': [72, 66, 63.75, 60.75, 60.75, 58.5, 58.5, 57, 57, 57, 52.5, 49.5, 45.3, 45, 39, 28.95, 40.5, 31.5, 49],
    'group_b': [71, 72, 60, 50, 57, 77, 81, 58, 62, 61, 73, 74, 76, 65, 66, 67, 67, 67, 69]
})

# %%
# Постройте в Python на одном графике 2 параллельных боксплота. На основании этого графика:
boxplot = df.boxplot(column=['group_a', 'group_b'])
# В целом больше времени на сайте проводят пользователи __________.
# Ответ: группы Б

# Разброс значений больше в _________.
# Ответ: группе А
