# %% [markdown]
# # 2.1. О чём этот модуль?
# Скачать презентацию, с которой работает автор, можно по ссылке (https://lms.skillfactory.ru/assets/courseware/v1/101b3d6f71c7d2f0688627334c3590b2/asset-v1:Skillfactory+DST-WEEKLY-2.0+08JULY2020+type@asset+block/SkillFactory_Module_on_Intro_Stats.pdf).
#
# ## О чём этот модуль?
# В этом модуле мы поговорим об основных понятиях математической статистики:
#
# - Что такое случайные величины?
# - Дискретные и непрерывные случайные величины.
# - Распределение вероятностей случайных величин.
# - Свойства случайных величин (математическое ожидание и дисперсия).
# - Нормальное распределение.
# - Центральная предельная теорема.

# %% [markdown]
# # 2.2. Важные термины
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Задание 2.2.1
# Количество контрактов, заключенных одним (случайно выбранным) менеджером за год — это ...
# Ответ: Дискретная случайная величина
#
# Вес одной (случайно выбранной) партии строительного материала — это...
# Ответ: Непрерывная случайная величина
#
# Время в пути от дома до работы — это...
# Ответ: Непрерывная случайная величина

# %% [markdown]
# # 2.3. Распределение вероятностей дискретной случайной величины
# ## Распределение вероятностей дискретной случайной величины
# Распределение вероятностей дискретной случайной величины — это набор ее возможных значений и их соответствующих вероятностей. Распределением этот набор называется потому, что он показывает, каким образом общая вероятность в 100% распределена по возможным исходам, какие исходы более или менее вероятны.
#
# Для дискретных случайных величин распределение вероятностей, как правило, задается таблицей или графиком.
#
# ## Пример
# Рассмотрим пример. Хипстер Ваня хочет открыть свой бизнес, но выбранная им сфера деятельности требует получения лицензии. Известно, что не всегда удается получить ее с первого раза. Допустим, нам удалось собрать информацию о том, сколько попыток понадобилось предшественникам Вани. Посмотрим на эту таблицу:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Задание 2.3.1
# Сколько студентов проходят курсы по социальным наукам?
# Ответ: 400

# %% [markdown]
# # Задание 2.3.2
# Сколько всего студентов обучается на этой платформе?
# Ответ: 1000

# %% [markdown]
# # Задание 2.3.3
# ![image.png](attachment:image.png)
# Ответ: в

# %% [markdown]
# # 2.4. Математическое ожидание
# ![image.png](attachment:image.png)

# %% [markdown]
# # Важно!
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Задание 2.4.1
# Каково математическое ожидание прибыли за первую неделю (в долларах)?
# 180
