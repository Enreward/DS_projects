# %% [markdown]
# # Хакатон по машинному обучению
# КАК БУДЕМ ОПРЕДЕЛЯТЬ ПОБЕДИТЕЛЯ?
#
# В этом нам опять поможет Kaggle.
# https://www.kaggle.com/t/0c44ab65036a42dca643eba82c81be3d
#
# 1. Вам нужно будет создать группу (или добавиться в уже существующую) для совместного участия в этом соревновании (определитесь в чате, кто создаст группу на kaggle).
# 2. Название группы на kaggle укажите аналогично названию группы в Slack.
#
# # РЕКОМЕНДАЦИИ ПО ВЫПОЛНЕНИЮ ПРОЕКТА
#
# - Добавьте новые данные в исходный датасет.
# - Сделайте разведку новых признаков аналогично предыдущим. Используйте визуализацию, поиск уникальных значений, очистку и поиск выбросов там, где это необходимо.
# - Включите новые признаки в анализ основных переменных, оцените их важность и вклад для модели, подумайте над тем, можно ли сгенерировать новые признаки на основе добавленных
# - Получите новое значение ROC AUC для новой модели и попробуйте улучшить ее результаты на основе подбора параметра регуляризации
# - Чтобы понять, к какому уровню вам стоит стремиться, достаточно взглянуть на таблицу лидеров соревнования.

# %% [markdown]
# # Послесловие
# На следующий день вы презентуете решение команде. Одного из присутствующих вы видите впервые (хотя его лицо кажется странно знакомым).
#
# Avatar
# Ребята, познакомьтесь с нашим новым директором по развитию! Константин приехал к нам из Москвы, у него большой опыт управления в банковской сфере. Он решил зайти посмотреть, чем мы тут занимаемся.
#
# Взгляд Коли, направленный на вас, как бы говорит: «Смотри не напортачь!».
#
# Вы уверенным голосом рассказываете о сути задачи, вашем подходе к решению и демонстрируете работу прототипа.
#
#     — … Таким образом, благодаря полученной точности модели мы можем быть уверены, что компьютер скажет «нет» клиенту с высоким риском дефолта.
#
# Вы мысленно отмечаете, как помрачнело лицо Коли, но затем переводите взгляд на директора по развитию: он выглядит довольным.
#
# Avatar
# Хорошая работа, стажёр! Хорошо, что не забыл про регуляризацию. Зайди ко мне в кабинет завтра после обеда – обсудим твое будущее в компании. И вы, Николай, тоже приходите!
#
# Николая директор по развитию упоминает уже не таким благодушным тоном и покидает кабинет. А вы остаётесь гадать, о каком же будущем он говорил...
#
#  ⭐ На этом всё! Спасибо, что были с нами. Не переключайтесь — новая серия выйдет совсем скоро!
