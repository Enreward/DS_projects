# %% [markdown]
# # 1. Вступление к модулю
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ### Переход от одной величины к нескольким
# ![image-3.png](attachment:image-3.png)
# ### Поиск «малых» событий с «большими» вероятностями
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ### Как влияет новая информация?
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Дополнительные материалы
# В качестве дополнительной литературы можем порекомендовать вам книгу «Гарри Поттер и методы рационального мышления»(https://hpmor.ru/).

# %% [markdown]
# # 2. Вероятность. Общие понятия
# Мы начнем с алфавита языка теории вероятностей — с понятия случайного эксперимента, элементарных исходов, их вероятностей и вероятностного пространства.
#
# Давайте вспомним пример с эклерами из вступительного видео. В нём случайным экспериментом является покупка эклеров.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Вероятность. Общие понятия (продолжение)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Условная вероятность
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Дополнительные материалы
# В качестве дополнительной литературы рекомендуем вам прочесть о Парадоксе Монти-Холла(https://habr.com/ru/post/101695/).

# %% [markdown]
# # 5. Задачи на условную вероятность
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Формула полной вероятности
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. Задача на формулу полной вероятности
# В презентации учебного материала, данного видеоурока, имеется техническая опечатка. При решении задачи, в пункте, где нужно, найти долю каждого типа клиентов среди уходящих клиентов, вместо 0. 06, в формуле должно быть значение 0. 006. В конспекте под видео предоставлены корректные данные.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. Формула Байеса
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Дополнительные материалы
# В качестве дополнительного источника рекомендуем вам:
# - Главу 20 из книги «Гарри Поттер и методы рационального мышления» (https://hpmor.ru/book/1/20/);
# - разбор аналогичной задачи про точность медицинских тестов(https://elementy.ru/bookclub/chapters/434328/Putevoditel_dlya_vlyublyonnykh_v_matematiku_Glava_iz_knigi);
# - немного о Байесовском подходе к вероятности(https://habr.com/ru/post/411659/).

# %% [markdown]
# # 9. Задача на обновление информации
