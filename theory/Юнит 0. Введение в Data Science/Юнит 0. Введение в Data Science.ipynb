# %% [markdown]
# # Введение в Data Science
#
# В этом Юните вы начнёте своё знакомство со сферой Data Science.
#
# СОДЕРЖАНИЕ ЮНИТА
#
# Для успешного выполнения практического задания вам понадобятся знания по следующим темам:
#
# - PYTHON-1-PYTHON-4. Эти модули включают в себя теорию и упражнения на отработку навыков, необходимых для выполнения проекта Git.
# - GIT-1. Инструмент разработки. Этот модуль расскажет вам о нюансах работы с git, важным инструментом в жизни любого разработчика.
# - Проект 0. «GitHub. Самый быстрый старт».
#
# Вы уже знаете, что в каждом юните содержится один практический проект, который вам нужно реализовать к дедлайну. Этот проект максимально приближен к реальным задачам Data Scientist'а. Все вопросы теории вы сразу можете отработать на практике.
#
# В этом Юните в качестве финального задания мы предлагаем вам сыграть в игру с компьютером. Представьте, что ваш противник (в нашем случае компьютер) может загадать любое число от 1 до 99. Ваша задача —угадать это число с минимального количества попыток. Почти чтение мыслей!
#
# Самое интересное, что сделать это можно с помощью базовых инструментов Python. Подробное описание и инструкции к выполнению проекта вы найдете в разделе Проект 0. GitHub. Самый быстрый старт.
#
# РЕЗУЛЬТАТЫ ЮНИТА
#
# В этом юните вы:
#
# 1. познакомитесь с основами синтаксиса Python и основными алгоритмами;
# 1. освоите работу с циклами и словарями;
# 1. научитесь обрабатывать текстовые данные;
# 1. узнаете, как организовать сложный код с помощью функций;
# 1. попробуете себя в роли разработчика и напишите свою первую программу;
# 1. загрузите свой первый проект на github и начнёте собирать портфолио датасаентиста.
#
# РЕКОМЕНДАЦИИ ПО ПРОХОЖДЕНИЮ ЮНИТА
#
# В теоретических модулях содержится всегда чуть больше информации, чем нужно для успешного выполнения проекта. Если по какой-то причине вы не успеваете пройти все-все задания до дедлайна, не переживайте! Вы всегда сможете вернуться к ним позднее. (на самом деле НЕТ, теории, практически всегда было недостаточно и приходилось тратить время на поиск и изучение доп материалов)

# %% [markdown]
# # PYTHON-1. Подготовка к работе
# # 1. Введение
#
# Приветствуем вас!
# Этот модуль направлен на то, чтобы познакомить вас с базовыми понятиями области через выполнение различных практических задач.
#
# Используя одни и те же слова, люди часто могут трактовать их совсем по-разному. Если участники проекта или сотрудники компании заранее не пришли к одному пониманию предмета, совместная работа у них вряд ли получится.
#
# Бывает и наоборот — люди решают внешне разные задачи, но по сути проходят один путь.
#
# - Антон оптимизирует работу компании, которая занимается доставкой.
# - Лиза пишет бэкенд веб-приложения.
# - Глеб открывает кофейню по франшизе.
#
# Разные задачи, но каждый строит модель проблемы, представляет данные, на которые будет опираться, планирует решение и реализует его подходящими инструментами.
#
#  Что будет результатами модуля?
# - Вы освежите в памяти или познакомитесь с ключевыми понятиями IT.
# - Вы решите ряд простых и не очень задачек и упражнений, чтобы лучше понять и запомнить суть этих понятий.
# - Вы познакомитесь с рядом простых инструментов, которые могут быть полезны уже сейчас: Zapier, Dialogflow, Gliffy и так далее.
# - На примерах вы увидите, как от любой проблемы можно прийти к решению,  двигаясь последовательно: создавая модель ситуации — собирая корректные данные — записывая с помощью UML или псевдокода план действий — реализуя с помощью кода или готовых сервисов созданный алгоритм.
# - Узнаете, что представляет собой язык Python.
# - Где его найти, как выбрать правильную версию, как подготовить среду, в которой вы сможете написать свою первую программу.
# - В конце модуля вы научитесь писать простейшие программы и узнаете, как их запускать.
# - Установим программную среду Anaconda — крутой инструмент для программирования и работы с данными. Старайтесь тщательно выполнять все пункты инструкции во время установки, так как это поможет избежать многих проблем в будущем. Разберёмся в интерфейсе Jupyter Notebook. Мы уверены, что вам понравится!
#
# Обратите внимание! Модуль по Github открывается одновременно с модулем "Python. Задачи по пройденным темам".

# %% [markdown]
# # 2. Введение в Python и его установка
#
# Мы приступаем к изучению языка программирования Python. В этом юните мы разберём, чем Python отличается от других языков программирования, какие у него есть преимущества и недостатки в сравнении с другими языками, актуальные и устаревшие версии Python.
#
# Python среди других языков программирования
# Язык программирования — это строго определённый набор правил, благодаря которому возможно взаимодействие человека с компьютером. Язык программирования — это тот инструмент, с помощью которого вы можете управлять компьютером.
#
# Сам по себе компьютер делать ничего не умеет, результат его работы и того, что он может — это огромный труд большого количества программистов. Все эти программисты и используют различные языки программирования, чтобы писать программы, которые будут выполняться вычислительными машинами.
#
# Получается, чтобы компьютер начал понимать, что вы от него хотите в написанной вами программе с выбранным языком программирования, ему нужна ещё одна программа, которая будет понимать и выполнять ваш язык программирования. А на чём должна быть написана программа, которая сможет выполнять ваш язык программирования? Получается, на другом языке программирования? Да! Между тем, эти языки разные: они делятся на низко- и высокоуровневые.
#
# Низкоуровневые языки работают непосредственно с аппаратной частью компьютера, поэтому скорость их работы, в отличие от высокоуровневых, выше.
#
# Процессор — сердце компьютера, различает только два сигнала, обычно их обозначают как "1" и "0", то есть либо сигнал есть, либо его нет. Процессор умеет работать только с командами, состоящими из нулей и единиц. Ещё такую последовательность единиц и нулей называют машинным кодом.
#
# Низкоуровневые языки уже состоят из набора таких команд, записанных в виде машинного кода, поэтому эти команды понятны компьютеру и могут выполняться сразу без дополнительных преобразований.
#
# У низкоуровневых языков есть ограничение — они не являются кроссплатформенными. Это значит, что машинный код, который вы получите на Windows, вы не сможете запустить на Linux и наоборот. Связано это с архитектурными особенностями этих платформ.
#
# Высокоуровневые языки в свою очередь сделаны так, чтобы один и тот же исходный код можно было запускать вне зависимости от операционной системы, на которой он запускается. Также синтаксис высокоуровневых языков программирования легче понять человеку, потому что он разработан для удобства работы программиста.
#
# Под синтаксисом языка программирования следует понимать набор правил, из которых строится программа. Если проводить аналогию с русским языком, синтаксис — это правила орфографии и пунктуации. В языке программирования есть строго определённый набор ключевых слов, которые описывают команды для компьютера. В этих словах важен каждый символ: любое несоответствие или неоднозначность того, что вы хотите донести до компьютера, вызовет ошибку. В большинстве языков важна в том числе и структура кода, который вы пишите, потому что это один из способов донести вашу мысль до вычислительной машины.
#
# Python как раз относится к таким языкам: здесь очень важно соблюдение положения ключевых слов в исходных текстах — без этого компьютер не поймёт, чего вы от него хотите.
#
# За удобство пользования приходится платить памятью. Программы, написанные на высокоуровневых языках, требуют для своей работы и хранения значительно больше памяти, чем низкоуровневые.
#
# Ниже приведена сводная таблица по преимуществам и недостаткам низко- и высокоуровневых языков программирования:
# ![image.png](attachment:image.png)
#
# Ещё языки программирования делятся на компилируемые и интерпретируемые.
#
# В компилируемых языках для преобразования исходного кода в машинный код используются специальные программы — компиляторы. Компиляторы преобразуют весь «человеческий» код в машинный перед началом работы, а на выходе получается новая скомпилированная программа, которую и выполняет компьютер.
#
#  Второй тип языков программирования —  интерпретируемые. Интерпретатор принимает удобный для восприятия человеком код и начинает построчно исполнять его, преобразуя каждую строку в машинный код.
#
# Отличие компилятора от интерпретатора в том, что последний не создаёт никакой новой программы, а просто берёт каждую строку вашей программы, преобразует её в такую форму, которая понятна для выполнения компьютеру, и исполняет её, а затем берёт следующую инструкцию. Делать он будет это до тех пор, пока не будут выполнены все строки вашего исходного файла, либо не встретится команда, обозначающая конец интерпретации.
#
# Python является интерпретируемым языком программирования, а более подробно процесс работы интерпретатора будет рассмотрен далее.
#
# Отвечая на вопрос, какое же место язык Python занимает среди всех языков программирования, можно сказать:
#
# Python — это высокоуровневый интерпретируемый кроссплатформенный язык программирования.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Версии Python
# До начала 2020 года существовало две принципиально разные версии Python. Но Python версии 2 прекратил свою поддержку в январе 2020 года. Последняя версия 2.7.18 была выпущена в апреле 2020.
#
# Актуальной версией Python является Python 3.  Если у вас не стоит конкретной задачи, то однозначно выбирайте Python 3. Но и здесь существует несколько различных типов:
#
# Старые версии, которые уже тоже не поддерживаются, например, версии старше Python 3.4, включительно. Они постепенно перестают поддерживаться разработчиками, а значит нет гарантий, что обнаруженные уязвимости и ошибки будут исправлены.
# Актуальные: любая из версий 3.5, 3.6, 3.7, 3.8. Постепенно ранние версии также прекращают свою поддержку, поэтому старайтесь пользоваться наиболее поздней из доступных версий. В данном курсе будем пользоваться версией Python 3.8.
# Версии, которые проходят тестирование и готовятся к официальному выпуску. Такие версии находятся в стадии разработки, а следовательно, подвержены возникновению большого количества ошибок и несовместимостей. Поэтому их не рекомендуется использовать в «боевых проектах».
# img  Актуальную информацию обо всех версиях можно узнать на официальном сайте Python [https://devguide.python.org/#status-of-python-branches].
#
# ## Плюсы и минусы Python
# Как и у любого языка программирования, у Python есть свои плюсы и минусы. Ознакомьтесь с ними в таблице ниже, а далее в этом разделе обсудим каждый пункт более подробно.
# ![image.png](attachment:image.png)
# Python вне зависимости от версии является интерпретируемым языком программирования. Компилятор же преобразует всю программу сразу, а потом выполняет её. Отсюда вытекает первый минус языка Python — это скорость его работы. Интерпретируемые языки затрачивают время на преобразование в машинный код во время выполнения самой программы, в отличие от компилируемых, которые делают это до момента начала выполнения.
#
# Но этот минус довольно условный, потому что в обычных рядовых задачах разница в скорости работы не заметна. Также этот недостаток с лихвой покрывается скоростью написания кода и возможностью лёгкой отладки кода, благодаря очень простому и «человекочитабельному» синтаксису. Это один из основных плюсов, которым Python выделяется среди остальных языков программирования.
#
#  Следующим плюсом является многогранность его применения:
#
# Во-первых,  Python является кроссплатформенным. Код, который вы напишете, будет работать на всех популярных платформах (Windows, Linux, Mac).
# Во-вторых, множество сфер применения, начиная от программирования микроконтроллеров, заканчивая алгоритмами машинного обучения и анализа данных, благодаря которым Python и приобрёл такую популярность. Также Python можно использовать для разработки игр и работы с компьютерной графикой. С помощью Python очень удобно автоматизировать рутинные задачи, которые могут быть связаны с администрированием различных систем. Также Python позволяет быстро и просто создавать сайты. Ну, а благодаря простоте написания кода он идеально подходит в качестве первого языка программирования.
# Ещё широкому распространению языка Python способствовало обилие дополнительных библиотек — богатая коллекция уже готовых решений неких задач другими программистами с подробной документацией (справочник, описывающий, как пользоваться языком программирования) того, что они сделали. Остаётся только найти их и адаптировать под свои задачи.
#
# В целом, Python — как автомобиль «на каждый день». Очень удобный и универсальный в использовании, но проигрывает в скорости менее комфортным и быстрым суперкарам. Вам не нужно очень долго учиться — сели и поехали. Уже через несколько занятий вы сможете писать свои собственные полноценные программы. Поэтому Python является отличным языком программирования для новичков.
# ![image-2.png](attachment:image-2.png)
# Но это совсем не значит, что он не может справляться с серьёзными задачами. Facebook, Instagram, Netflix, Google, Yandex — все эти IT-гиганты используют Python в качестве рабочего инструмента.
#
# Ниже приведены рейтинги языка программирования Python:
#
# Рейтинг [https://spectrum.ieee.org/at-work/tech-careers/top-programming-language-2020https://spectrum.ieee.org/at-work/tech-careers/top-programming-language-2020] института инженеров электротехники и электроники (IEEE) за 2020 год. Python первый по широте использования (август 2020):
# ![image-3.png](attachment:image-3.png)
# Индекс TIOBE [https://ru.wikipedia.org/wiki/Индекс_TIOBE]. Третий по популярности в запросах поисковых системах (август 2020):
# ![image-4.png](attachment:image-4.png)
# Индекс PYPL [https://ru.wikipedia.org/wiki/Индекс_TIOBE]. Первый по популярности в запросах инструкций к Google (август 2020):
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Где найти Python?
# Чтобы приступить к работе, сперва нужно установить себе интерпретатор Python. Не будем подробно останавливаться на моменте с проверкой того, какая версия Python уже установлена на вашей системе. Зачастую на Linux и MacOS Python установлен по умолчанию. На Windows он не стоит по умолчанию.
#
# Нет никаких ограничений количества версий Python, которые могут быть у вас установлены. Также нет никаких проблем, если у вас будет установлен Python 2 и 3 версий. При работе вам просто нужно будет указать ту версию, с которой вы хотите работать.
#
# Итак, скачать себе интерпретатор Python можно с официального сайта в разделе Downloads. Если вам нужна какая-то специфическая версия, то её можно найти во вкладке All releases. Напоминаем, что в данном курсе нас будет интересовать версия 3.8. При скачивании вы не найдёте версию 3.8 в явном виде, но будут доступны её версии 3.8.1 или 3.8.3, например. Скачивать можете любую версию формата 3.8.х.
# ![image.png](attachment:image.png)
# Тем, кто захочет проверить наличие интерпретатора Python на своём компьютере, можно воспользоваться вот этой статьёй [https://ru.wikihow.com/узнать-версию-Python-(на-компьютере)].

# %% [markdown]
# Задание 2.8
# Установка интерпретатора Python
# Установите интерпретатор Python. В данном задании будет рассматриваться установка интерпретатора Python на операционную систему Windows 10. С более подробными инструкциями по установке на платформы Linux и Mac вы можете ознакомиться на данных ресурсах:
#
# Linux:
# инструкция https://python-scripts.com/install-python-3-8-linux
# видео https://www.youtube.com/watch?v=ox4joJFbfLM
#
#  MacOS:
# инструкция https://pythonru.com/baza-znanij/kak-skachat-i-ustanovit-python-na-mac-oc-x
# видео https://www.youtube.com/watch?v=0KEI-GlH3zc
#
# В качестве дополнения на официальном ресурсе [https://wiki.python.org/moin/BeginnersGuide/Download] вы можете найти информацию, о  том как найти и выбрать интерпретатор для своей операционной системы.
# А мы с вами приступим к установке интерпретатора Python на Windows. Перед началом установки вы можете посмотреть данные видео, чтобы ознакомиться с тем, что вам предстоит выполнить:
#
# Видео 1 [https://www.youtube.com/watch?v=OccKDgJBuGI]. В качестве бонуса  установка текстового редактора Sublime Text.
# Видео 2 [https://www.youtube.com/watch?v=LKVVtVVkj7Q]. Здесь рассматривается настройкой компонентов, необходимых для установки.
# Для установки необходимо выполнить следующие шаги:
#
# После скачивания с официального сайта[python.org] будет доступен файл с расширением .exe. Его необходимо запустить.
# ![image.png](attachment:image.png)
#
# Далее вам нужно выбрать Customize installation. И не забудьте поставить галочку напротив Add Python 3.8 to PATH, это позволит в дальнейшем не искать Python по всему компьютеру, а пользоваться удобной ссылкой на интерпретатор Python.
# ![image-2.png](attachment:image-2.png)
#
# На следующем шаге представлено, что будет установлено вместе с интерпретатором. Здесь два важных момента: pip — пакетный менеджер, о котором мы будем говорить дальше. И IDLE, которая представляет собой среду для разработки. Убедитесь, что напротив этих двух пунктов стоят галочки и можно переходить далее, нажав кнопку Next.
# ![image-3.png](attachment:image-3.png)
#
# На этом шаге вам необходимо скопировать и сохранить путь, куда будет установлен ваш интерпретатор. Данная информация будет нужна в при работе со средой разработки. Вы можете установить интерпретатор в любую папку, важно запомнить эту папку. Для начала установки необходимо нажать кнопку Install.
# ![image-4.png](attachment:image-4.png)
#
# После успешной установки вы должны увидеть следующее окно:
# ![image-5.png](attachment:image-5.png)
#
# Чтобы убедиться, что интерпретатор Python успешно установился, да ещё и с нужной версией, необходимо нажать сочетание клавиш Win + R, в открывшемся окне ввести команду cmd и нажать клавишу OK.
# ![image-6.png](attachment:image-6.png)
#
# В открывшейся консоли ввести команду python, которая запустит интерпретатор Python. Если интерпретатор Python не запустится, вероятно вы забыли установить галочку на втором шаге установки. Повторите все шаги, начиная со второго. Также проверьте, чтобы версия вашего интерпретатора была формате 3.8.x.
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# # 3. Как работать с документацией по Python
# Теперь, когда вы знаете, как установить и запустить интерпретатор Python, самое время разобраться, как и где искать информацию о том, как пользоваться всеми возможностями языка Python.
#
# В прошлом юните мы частично познакомились с официальным сайтом [python.org], откуда скачивали интерпретатор. Давайте рассмотрим другие разделы этого сайта.
#
# Раздел About
# ![image.png](attachment:image.png)
# В этом разделе можно познакомиться с тем, где использовать Python. Популярные проекты и библиотеки представлены во вкладке Applications. Например, это может быть разработка web- или десктопных приложений, либо проекты в областях, связанных с наукой или обучением.
#
# Во вкладке Getting Started можно получить полезную информацию для тех, кто только начинает свой путь в пользовании языка Python. Например, как установить Python, какие существуют среды для разработки. Все эти моменты мы с вами будем рассматривать в данном модуле.
#
# Раздел Documentation
# ![image-2.png](attachment:image-2.png)
# В разделе  Documentation можно найти информацию как для начинающего программиста, так и для тех, кто хочет прокачать свои навыки. Здесь представлен перечень литературы, с помощью которой можно изучить основы языка Python и другие расширенные темы.
#
# Во вкладке Beginner's Guide вы найдёте всю информацию о подборе интерпретатора, различных руководствах или web-ресурсах.
#
# Во вкладке Developer’s Guide можно ознакомиться с основами работы таких вещей, которые должен знать разработчик, который хочет профессионально заняться разработкой. Например, Git или тестирование своего кода.
#
# Во вкладке PythonBooks представлен небольшой список литературы, которым можно воспользоваться для дополнительного изучения Python. В том числе, можно найти список литературы на русском.
#
# Документация стандартной библиотеки
# Ещё одним из плюсов в выборе Python как первого и основного языка программирования является очень подробная и полная документация стандартной библиотеки. Для актуальной версии 3 интерпретатора документацию можно найти по ссылке [https://docs.python.org/3/].
#
# Документацию для специфической версии интерпретатора можно найти здесь [https://www.python.org/doc/versions/].
# Возможности стандартной библиотеки довольно разнообразны, описать всё в рамках данного юнита не представляется возможным. Да и не факт, что вы столкнётесь с чем-то в реальных практических задачах. А столкнувшись с поиском решения каких-то проблем, сначала обратитесь к стандартной библиотеке — возможно, там уже содержится модуль (библиотека), который поможет вам.
#
# Модулем (библиотекой) в Python называется любая программа. Даже простейший скрипт, содержащий всего одну строку print(‘Hello World’), можно назвать модулем. Программисты пишут модули, решающие самые разнообразные задачи, и публикуют в свободном доступе. Вы можете подключать их и использовать в своих программах, а не «изобретать велосипед заново».
#
# Очень кратко разберём основные разделы:
#
# Модули для работы с текстовым форматом данных. Например, строки, регулярные выражения.[https://docs.python.org/3/library/text.html]
# Расширенные типы данных. Позволяют работать с датами, очередями, массивами. [https://docs.python.org/3/library/datatypes.html]
# Модули для работы с числами. Модули с расширенными математическими операциями. [https://docs.python.org/3/library/numeric.html]
# Взаимодействие с файловой системой. [https://docs.python.org/3/library/filesys.html]
# Работа с операционной системой. [https://docs.python.org/3/library/allos.html]
# Простейший графический интерфейс. [https://docs.python.org/3/library/tk.html]
#
# Полный список встроенных модулей можно найти здесь. [https://docs.python.org/3/library/index.html]
#
# Коротко рассмотрим два основополагающих раздела.
#
# Встроенные функции и типы данных
# Итак, первое, что стоит держать в голове — это встроенные функции [https://docs.python.org/3/library/functions.html]. Их не нужно знать наизусть. С частью, возможно, вы не столкнётесь, а какие-то будут использоваться очень часто, например len(), list(), min()/max().
#
# Встроенных типов [https://docs.python.org/3/library/stdtypes.html] меньше, чем встроенных функций, и их нужно знать, потому что это основа для построения ваших программ. Специально их учить не нужно, на практике вы и так их запомните. К основным типам данных можно отнести целые числа, числа с плавающей запятой, строки, списки и словари. Важно представлять, каким функционалом обладают эти типы данных. Если вы забыли или захотите со временем узнать что-то новое, то всегда можете обратиться к документации.
#
# Подробнее со встроенными типами данных мы познакомимся в следующих модулях.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://wiki.python.org/moin/RussianPythonBooks

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Установка IDE и необходимых пакетов
#
# Пришло время разобрать вопрос, связанный с тем, где можно писать код, который будет выполнять интерпретатор. Для написания простейшей программы вам подойдет даже блокнот. Ведь программа для Python представляет собой простой текстовый файл с расширением .py, который содержит исходный код. Далее этот файл нужно передать интерпретатору, чтобы он выполнил описанные вами инструкции.
#
# Когда ваши программы становятся всё сложнее и сложнее, то средств простого блокнота не хватает, и писать программы становится всё менее и менее удобно.
#
# Для помощи и упрощения написания кода есть специализированные текстовые редакторы, которые содержат в себе плагины, которые начинают подсвечивать синтаксис, показывать вам синтаксические ошибки ещё до момента запуска вашей программы. Примерами таких тестовых редакторов могут быть Notepad++ [https://notepad-plus-plus.org/] либо Sublime Text.
#
# На самом деле их большое количество, и нет никакого смысла что-то рекомендовать. Пользуйтесь привычным для вас текстовым редактором и поищите дополнения для него для работы с Python.
#
# Перечень редакторов [https://wiki.python.org/moin/PythonEditors], которые поддерживают работу с Python.
# Интегрированная среда разработки
# При установке интерпретатора Python на Windows вместе с ним устанавливается программа под названием IDLE.
#
# IDLE — это интегрированная среда разработки и обучения на языке Python (англ. Integrated Development and Learning Environment). После установки интерпретатора Python вам не нужно будет искать дополнительных программ, чтобы приступить к работе. Удобный графический интерфейс для работы с интерпретатором Python будет сразу доступен.
#
# Но возможности IDLE ограничены, она больше подходит для ознакомительных целей. Чтобы снять с себя рутинные задачи при написании кода, такие как поиск синтаксических ошибок, автодополнение кода или отладка программ, и сконцентрироваться именно на решении задачи, были разработаны специальные программы, которые имеют общее название IDE.
#
# IDE — интегрированная среда разработки (англ. Integrated Development Environment). Простыми словами можно сказать, что это программы, которые позволяют писать другие программы.
# ![image.png](attachment:image.png)
# IDE состоит из трёх основных объектов:
# - текстового редактора, который позволяет писать код;
# - транслятора (в случае Python — интерпретатора), который исполняет ваш код;
# - отладчик, который позволяет пошагово изучить вашу программу и облегчить поиск ошибки.
#
# Существует большое количество сред разработки, отличающихся наличием тех или иных функций, которые упрощают жизнь разработчика. Например, это может быть подсветка синтаксиса, автодополнение кода, взаимодействие с системами контроля версий и многое другое. Опять же нет каких-то однозначных критериев, какую среду выбрать. Вопрос привычки либо удобства пользования. Возможно, решающим моментом для вас станет наличие тех или иных фишек для работы.
#
# - С перечнем IDE, позволяющих работать с Python, можно ознакомиться здесь [https://wiki.python.org/moin/IntegratedDevelopmentEnvironments]. Для первого ознакомления можно выделить несколько популярных IDE: PyCharm, Spyder, Visual Studio, Eclipse + PyDev.
# - Сравнительный анализ IDE для Python можно посмотреть здесь [https://tproger.ru/translations/python-ide/].
#
# В рамках данного курса мы будем работать с программным обеспечением компании JetBrains, а конкретно IDE PyCharm. Существует две версии данного продукта: Professional Edition и Community Edition (CE).
#
# Версия PyCharm CE является бесплатной и содержит все необходимые функции для комфортного написания кода. Версия Professional содержит углублённые интеграции в отдельные сферы работы с Python, например Web-разработка.
#
# Вы можете скачать PyCharm Professional Edition и в течение месяца пользоваться бесплатным пробным периодом.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Задание 4.3
# Установка PyCharm CE
# Вашим практическим заданием будет скачать PyCharm CE с официального сайта JetBrains [https://jetbrains.ru/], установить его себе и создать в нём новый Python-проект, добавить файл script.py и запустить его.
#
# Перед началом установки вы можете посмотреть короткое видео [https://www.youtube.com/watch?v=uWLwvhbbEe4], в котором разбирается процесс установки PyCharm и основные моменты работы с этой средой.
#
# Основные шаги, которые вам необходимо выполнить:
#
# 1. Скачать PyCharm СЕ c официального сайта[https://www.jetbrains.com/ru-ru/pycharm/download/#section=windows].
# 1. Установить его, используя данное пошаговое руководство[https://pythonru.com/baza-znanij/poshagovaja-ustanovka-pycharm].
# 1. Далее на создании нового проекта мы остановимся поподробнее. Под цифрой 1 вы можете указать название вашего проекта и путь, где он будет расположен. Далее нужно выбрать интерпретатор, с которым будет работать ваш проект. Для этого под цифрой 2 нужно нажать на кнопку ....
# ![image.png](attachment:image.png)
# 1. Далее нужно выбрать системный интерпретатор и указать путь до него. Поле может заполняться автоматически. Но если это не произошло, то нужно указать тот путь, который вам необходимо было сохранить, когда вы устанавливали интерпретатор.
# ![image-2.png](attachment:image-2.png)
# 1.  итоге у вас должно получиться следующее, и нужно нажать на кнопку Create.
# ![image-3.png](attachment:image-3.png)
# 1. Далее вам нужно создать Python-файл c названием script.py. Для это нужно правой кнопкой мыши нажать на ваш проект и выбрать New -> Python File. В данном случае расширение .py не нужно, PyCharm автоматически подставит его за вас.
# ![image-4.png](attachment:image-4.png)
# 1. В итоге перед вами должна открыться вот такая рабочая область. Область 1 — это древовидная структура вашего проекта. Здесь будут все файлы вашего проекта. Область 2 — это текстовый редактор, в котором вы пишете свой код.
# ![image-5.png](attachment:image-5.png)
# 1. В области 2 напишите строку:
# ```print("Hello World")```
# И, кликнув правой кнопкой мыши в области 2, выберите зелёный треугольник, чтобы запустить вашу первую программу.
# ![image-6.png](attachment:image-6.png)
# 1. В результате выполнения вы должны увидеть сообщение Hello World.
# ![image-7.png](attachment:image-7.png)
# Поздравляем, вот вы и написали свою первую программу на языке Python!

# %% [markdown]
# # 5. Пакетные менеджеры и виртуальное окружение
# Следующая важная тема, которую мы с вами затронем — это работа с зависимостями. Под зависимостями мы с вами будем понимать набор модулей и библиотек, которые нужны вашему проекту.
#
# Пакетные менеджеры
# Мы уже разбирали модули, которые содержатся в стандартной библиотеке. Ещё модули можно объединять в наборы файлов, и тогда этот набор называется пакетом. Хоть в стандартной библиотеке и немало модулей и пакетов, но их функционал достаточно ограничен.
#
# Поэтому существует так называемый «каталог пакетов Python» (PyPI (аббр. от англ. Python Package Index), где содержатся пакеты, написанные другими разработчиками, и они решили поделиться ими. Все эти пакеты хранятся в репозитории, который можно найти на сайте [pypi.org]. Каждый проект содержит описание, ссылки на исходный код и документацию на тему того, как пользоваться представленным решением.
#
# Для того чтобы установить себе эти пакеты, существует ещё один вид программ, называемых пакетными менеджерами.
#
# Пакетный менеджер ,или система управления пакетами, используется для установки и управления программными пакетами. Они помогают вам не вдаваться в подробности, где взять ту или иную библиотеку, как её установить на свой компьютер. Вместо этого вам представлен удобный интерфейс, позволяющий с помощью одной команды установить или удалить пакет, зная его название.
#
# Для Python можно выделить три основных пакетных менеджера:
# - pip;
# - pipenv;
# - conda.
#
# Менеджер pip является модулем, написанным на Python, и позволяет работать только с установкой Python-пакетов.
#
# Pipenv использует связку pip и virtualenv, что упрощает их использование с помощью одного интерфейса командной строки.
#
# Conda обладает немного большим функционалом и может устанавливать пакеты не только для Python. Плюс conda решает некоторые вопросы, связанные с установкой пакетов, которые используют сложные зависимости, в том числе платформозависимые (особенно этим грешат различные научные пакеты).
#
# Виртуальные окружения
# При создании программ они могут нуждаться в каких-то внешних модулях и пакетах, которые нужны им для работы. Как мы говорили ранее, такой набор модулей и пакетов, которые нужны проекту для его работы, называется зависимостями.
#
# В мире программирования есть два подхода к хранению зависимостей:
#
# Каждый проект обладает собственным набором зависимостей, которые доступны только ему.
# Все проекты используют единый набор зависимостей, которые ещё называют общесистемным.
# Большая проблема Python — использование подхода с общесистемным набором зависимостей по умолчанию. Суть подхода заключается в том, что все модули устанавливают в одно место на вашем компьютере. В вашей системе установлен интерпретатор (или несколько), и все зависимости, которые вы ставите, например, с помощью модуля pip, ставятся в папку с этим интерпретатором. Таким образом, любой проект, использующий этот интерпретатор, будет использовать все модули, которые в нём установлены.
# ![image.png](attachment:image.png)
# Отсюда вытекают следующие проблемы:
#
# Модули различаются лишь названиями, то есть нельзя иметь одновременно два установленных одинаковых модуля разных версий. Нельзя одновременно поставить pandas-0.21 и pandas-0.24.
# Нет простого способа экспортировать весь список использовавшихся в вашем проекте модулей для развёртывания в другом месте. pip по умолчанию выдаст все модули, установленные в системе.
# Решить эти недостатки позволяют так называемые виртуальные окружения (англ. Virtual Environments). Вы можете создать «виртуальное окружение», внутри которого копируется интерпретатор, от которого данное окружение было создано, и стандартные модули (os, sys, etc…).
#
# То есть для проекта появляется мини-копия интерпретатора, которая доступна только ему. Если вы захотите установить дополнительные модули для выбранного проекта, то все зависимости будут установлены в папку текущего проекта, а не в общесистемную папку.
#
# Более того, если вы захотите установить дополнительные модули из данного виртуального окружения, то пакетный менеджер установит их в локальную папку окружения, а не в общесистемную папку. То есть вы получаете локальное хранение зависимостей, которые теперь не конфликтуют друг с другом и доступны только для выбранного проекта.
#
# Создавая виртуальное окружение, вы изолируетесь от других проектов. Например, на картинке ниже находится три разных интерпретатора Python версий 2.7, 3.6, 3.4, и для каждого из них доступен свой набор модулей. В каждом из виртуальных окружений доступны два модуля — Py2neo и Django, но различных версий. В общесистемном подходе к хранению зависимостей вы бы могли хранить только одну версию каждого из модулей.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Виртуальное окружение позволяет:
# при запаковке интерпретатора с проектом в исполняемый файл с помощью, например, cx_freez уменьшить объём занимаемого скриптом пространства;
# использовать для реализуемого проекта только ту версию пакета, которая нужна для этого проекта.
# ![image.png](attachment:image.png)

# %% [markdown]
# Задание 5.2
# Создание виртуального окружения
# Про работу с пакетными менеджером pip и создание виртуальных окружений с помощью PyCharm подробно можно прочитать здесь [https://habr.com/ru/post/491916/].
# Вашим заданием будет самостоятельная настройка виртуального окружения. Для того чтобы настроить виртуальное окружение, вам необходимо:
#
# В PyCharm создайте новый проект с помощью вкладки File -> New Project...
# ![image.png](attachment:image.png)
# Далее необходимо создать виртуальное окружение. В предложенном диалоговом окне выбираем New environment using Virtualenv. Убеждаемся, что в качестве базового интерпретатора стоит Python3.8, который вы устанавливали. Нажимаем на кнопку Create.
# ![image-2.png](attachment:image-2.png)
# Далее во вкладке под названием File выберите вкладку Settings, либо во вкладке PyCharm вкладку Preferences в зависимости от вашей ОС. В появившемся диалоговом окне необходимо найти Project Interpreter. Чтобы добавить пакеты, вам нужно нажать +.
# ![image-3.png](attachment:image-3.png)
# Установите пакеты requests и beautifulsoup4 плюс ещё один на ваш выбор.
# ![image-4.png](attachment:image-4.png)
# Нужно будет подождать некоторое время, пока пакеты будут скачаны на ваш компьютер. Проверить работоспособность можно, выполнив следующий код. Он должен выполниться без ошибок.
#
# ```import requests
# import bs4```

# %% [markdown]
# 6. Интерпретатор Python
# Мы с вами разобрали моменты, связанные с рабочей средой, поиском и установкой модулей. Теперь пришло время суммировать информацию и написать свою первую программу.
#
# Давайте ещё раз вспомним работу интерпретатора, той программы, которая будет выполнять написанную вами программу. Интерпретатор берёт каждую строку вашей программы, преобразует её в такую форму, которая понятна для выполнения компьютеру, и исполняет её, а затем берёт следующую инструкцию. Делать он будет это до тех пор, пока не будут выполнены все строки вашего исходного файла либо не встретится команда, обозначающая конец интерпретации.
# ![image.png](attachment:image.png)
# Python выполняет предварительную обработку исходных кодов и делает их компиляцию в промежуточный код, называемый ещё байт-кодом. Каждая строка в исходном коде транслируется в группы инструкций байт-кода для повышения скорости выполнения программы, потому что с набором байт, тех самых единиц и нулей, компьютер умеет очень хорошо работать.
#
# После компиляции в байт-код рядом с файлом с исходным кодом создастся файл с таким же названием, но расширение у него будет .pyc.
#
# Такой файл с скомпилированным байт-кодом создаётся каждый раз, когда вы модифицируете свою программу. Если вы ничего не меняли, а просто повторно запустили свою программу, то процесс компиляции пропускается и выполняется сразу байт-код. И вот как раз этот байт-код выполняется построчно, то есть выполняется не строка исходного текста, а её представление в виде набора единиц и нулей. Поэтому язык программирования Python является интерпретируемым языком программирования.
#
# В общем виде процесс работы интерпретатора выглядит так:
# ![image-2.png](attachment:image-2.png)
# Давайте теперь попробуем самостоятельно запустить свою программу с помощью интерпретатора, а не с помощью графического интерфейса PyCharm. Для начала запустим Terminal в PyCharm.
# ![image-3.png](attachment:image-3.png)
# Если вы используете виртуальное окружение, то у вас будет высвечиваться вот такая приставка.
# ![image-4.png](attachment:image-4.png)
# Если её нет, то вы работаете с системным интерпретатором, и все пакеты, которые вы устанавливаете, будут доступны всем проектам, которые работают с этим системным интерпретатором.
#
# Далее вам нужно запустить файл script.py, который мы создавали ранее. Но сделать это нужно в Terminal, с помощью команды:
#
# ```script.py```
# После чего вы увидите приветственное сообщение Hello World:
# ![image-5.png](attachment:image-5.png)
# Это ещё один способ, с помощью которого вы можете запускать свои программы. Да, он не всегда удобный, но не все операционные системы бывают с графическим интерфейсом. Программист не должен бояться терминала и должен уметь работать с ним.
#
# Далее мы установим с вами пакет c помощью модуля pip через терминал. Для этого в терминале необходимо выполнить команду:
#
# ```pip install numpy```
# В данном случае мы устанавливаем модуль numpy, который реализован для эффективной работы с большими объёмами однотипных данных, например, числами. Опять же установка займёт некоторое время.
#
# И в заключение, c помощью команды
#
# ```pip freeze```
# вы можете получить список всех пакетов, которые установлены в текущем окружении, неважно, виртуальное оно или системное.

# %% [markdown]
# # Задание 6.1
# Итоговое задание
# Чтобы закрепить пройденный материал, вам необходимо будет самостоятельно выполнить следующее задание.
#
# 1. Установить на свой компьютер интерпретатор Python версии 3, но отличный от версии 3.8.
# 1. Создать в PyCharm два проекта, для каждого создать новое виртуальное окружение.
# 1. Установить в каждое окружение по 2 пакета, отличных от тех, которые использовались ранее. Причём один пакет в каждом окружении должен отличаться только версией. Для этого вам самостоятельно нужно найти, как с помощью модуля pip установить пакет с указанием определённой версии.
# 1. С помощью команды pip freeze сравнить результат одного и второго виртуального окружения.
